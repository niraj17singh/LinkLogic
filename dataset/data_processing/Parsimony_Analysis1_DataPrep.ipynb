# %% [markdown]
# ### Experiment4: Creating Benchmark

# %%
import pandas as pd
import json
import random
import pickle
random.seed(1234)

# %%
# Read entity mapping
e2id_path = open("/Users/niraj/Desktop/LinkLogic/akbc2021/akbc_2021/OpenKE/benchmarks/fb14/entity2id.txt", "r")
e2id = {}
for line in e2id_path:
    line = line.strip()
    e, ids = line.split("\t")
    e2id[e] = int(ids)
rev_e2id = {v: k for k, v in e2id.items()}

# %%
# Read relation mapping
r2id_path = open("/Users/niraj/Desktop/LinkLogic/akbc2021/akbc_2021/OpenKE/benchmarks/fb14/relation2id.txt", "r")
r2id = {}
for line in r2id_path:
    line = line.strip()
    r, ids = line.split("\t")
    r2id[r] = int(ids)
rev_r2id = {v: k for k, v in r2id.items()}

# %%
path = "/Users/niraj/Desktop/LinkLogic/akbc2021/akbc_2021/OpenKE/benchmarks/fb13_resplit/entity_names_to_types.csv"
data = pd.read_csv(path)
e2type = {}
for row in data.iterrows():
    e2type[row[1][0]] = row[1][1]

# %%
tuning_path = "../../../../akbc2021/akbc_2021/OpenKE/benchmarks/fb13_resplit/commonsense_benchmark_for_tuning_v2.json"
analysis_path = "../../../../akbc2021/akbc_2021/OpenKE/benchmarks/fb13_resplit/commonsense_benchmark_for_analysis_v2.json"

# %%
data = {}
with open(tuning_path) as f:
    data["tuning"] = json.load(f)

with open(analysis_path) as f:
    data["analysis"] = json.load(f)

# %%
train_path = "/Users/niraj/Desktop/LinkLogic/akbc2021/akbc_2021/OpenKE/benchmarks/fb14/train.txt"
test_path = "/Users/niraj/Desktop/LinkLogic/akbc2021/akbc_2021/OpenKE/benchmarks/fb14/test.txt"
valid_path = "/Users/niraj/Desktop/LinkLogic/akbc2021/akbc_2021/OpenKE/benchmarks/fb14/valid.txt"

train_path = open(train_path)
test_path = open(test_path)
valid_path = open(valid_path)
graph = {}
for t in train_path:
    t = t.strip()
    e1, r, e2 = t.split("\t")
    graph[e1, r, e2] = "train"

for t in test_path:
    t = t.strip()
    e1, r, e2 = t.split("\t")
    graph[e1, r, e2] = "test"
    
for t in valid_path:
    t = t.strip()
    e1, r, e2 = t.split("\t")
    graph[e1, r, e2] = "valid"

# %%
n_instance = 100

# %%
#1. Sample head entity
#2. Sample relation
#3. Sample tail entity

# %% [markdown]
# ### 1. Non sensical benchmark

# %%
triple = []

while len(triple) < n_instance:
    head_idx = random.randint(0, len(e2id)-1)
    rel_idx = random.randint(0, len(r2id)-1)
    tail_idx = random.randint(0, len(e2id)-1)
    
    # Ramdomly sample triples with head entity of Person type
    if e2type[rev_e2id[head_idx]] == "Person":
        triple.append([rev_e2id[head_idx], rev_r2id[rel_idx], rev_e2id[tail_idx]])

with open(f'data/data_4a.pickle', 'wb') as handle:
    pickle.dump(triple, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### 2. Different Family

# %%
triple = []

while len(triple) < n_instance:
    head_idx = random.randint(0, len(e2id)-1)
    rel_idx = random.randint(0, len(r2id)-1)
    tail_idx = random.randint(0, len(e2id)-1)
    
    if e2type[rev_e2id[head_idx]] == "Person" and \
        rev_r2id[rel_idx] in ["children", "parents", "spouse", "sibling"] and \
        e2type[rev_e2id[tail_idx]] == "Person":
        
        # If randomly sampled triple is not in graph, then append it to the triple list
        if (rev_e2id[head_idx], rev_r2id[rel_idx], rev_e2id[tail_idx]) not in graph:
            triple.append([rev_e2id[head_idx], rev_r2id[rel_idx], rev_e2id[tail_idx]])
        else:
            print('in graph', [rev_e2id[rand_idx], rev_r2id[rand_idx], rev_e2id[rand_idx]])

for t in triple:
    assert (t[0], t[1], t[2]) not in graph

# Store the triples 
with open(f'data/data_4b.pickle', 'wb') as handle:
    pickle.dump(triple, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### 3. Distance Family

# %%
triple = []
family_rel = ["children", "parents", "spouse", "sibling"]

while len(triple) < n_instance:
    
    # Sample random triple from the graph
    idx = random.randint(0, len(e2id)-1)
    t = list(graph.keys())[idx]
    
    # Swap the relation for the true triple in the graph
    if t[1] in family_rel:
        swap_rel = random.randint(0,3)
        
        # Make sure the randomly selected relation doesn't match with the query relation
        if family_rel[swap_rel] != t[1]:
            
            # If the perturbed triple is not in the graph, add to the list
            if (t[0], family_rel[swap_rel], t[2]) not in graph:
                triple.append([t[0], family_rel[swap_rel], t[2]])
                print(t)
                print([t[0], family_rel[swap_rel], t[2]])

# Verify all the triples are not in the graph
for t in triple:
    assert (t[0], t[1], t[2]) not in graph

# Store the triples 
with open(f'data/data_4c.pickle', 'wb') as handle:
    pickle.dump(triple, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# ('muriel_humphrey', 'spouse', 'hubert_humphrey')
# ['muriel_humphrey', 'sibling', 'hubert_humphrey']
# ('stilicho', 'spouse', 'honorius')
# ['stilicho', 'parents', 'honorius']
# ('elisabeth_of_parma', 'children', 'philip_duke_of_parma')
# ['elisabeth_of_parma', 'spouse', 'philip_duke_of_parma']
# ('stokely_carmichael', 'spouse', 'miriam_makeba')
# ['stokely_carmichael', 'sibling', 'miriam_makeba']
# ('charles_duke_of_lower_lorraine', 'children', 'gerberga_of_lower_lorraine')
# ['charles_duke_of_lower_lorraine', 'spouse', 'gerberga_of_lower_lorraine']
# ('anna_radziwill', 'children', 'janusz_iii_mazowiecki')
# ['anna_radziwill', 'sibling', 'janusz_iii_mazowiecki']
# ('dobroslav_ii', 'parents', 'mihailo_i_vojislav')
# ['dobroslav_ii', 'sibling', 'mihailo_i_vojislav']
# ('hugh_de_stafford_2nd_earl_of_stafford', 'children', 'katherine_de_stafford')
# ['hugh_de_stafford_2nd_earl_of_stafford', 'parents', 'katherine_de_stafford']
# ('hamengkubuwana_vi', 'children', 'hamengkubuwana_vii')
# ['hamengkubuwana_vi', 'parents', 'hamengkubuwana_vii']
# ('gaius_marius', 'children', 'gaius_marius_the_younger')
# ['gaius_marius', 'spouse', 'gaius_marius_the_younger']
# ('lydia_lopokova', 'spouse', 'john_maynard_keynes')
# ['lydia_lopokova', 'sibling', 'john_maynard_keynes']
# ('shah_rukh', 'parents', 'timur')
# ['shah_rukh', 'sibling', 'timur']
# ('jens_arup_seip', 'parents', 'hans_kristian_seip')
# ['jens_arup_seip', 'spouse', 'hans_kristian_seip']
# ('alfonso_ii_duke_of_ferrara', 'parents', 'renee_of_france')
# ['alfonso_ii_duke_of_ferrara', 'children', 'renee_of_france']
# ('john_spencer_churchill_7th_duke_of_marlborough', 'children', 'george_spencer_churchill_8th_duke_of_marlborough')
# ['john_spencer_churchill_7th_duke_of_marlborough', 'spouse', 'george_spencer_churchill_8th_duke_of_marlborough']
# ('hodierna_of_tripoli', 'parents', 'baldwin_ii_of_jerusalem')
# ['hodierna_of_tripoli', 'sibling', 'baldwin_ii_of_jerusalem']
# ('ankhesenpaaten', 'spouse', 'ay')
# ['ankhesenpaaten', 'sibling', 'ay']
# ('isabel_de_clare_4th_countess_of_pembroke', 'spouse', 'william_marshal_1st_earl_of_pembroke')
# ['isabel_de_clare_4th_countess_of_pembroke', 'sibling', 'william_marshal_1st_earl_of_pembroke']
# ('louise_marie_therese_of_france', 'parents', 'caroline_ferdinande_louise_duchesse_de_berry')
# ['louise_marie_therese_of_france', 'sibling', 'caroline_ferdinande_louise_duchesse_de_berry']
# ('virginia_valli', 'spouse', 'charles_farrell')
# ['virginia_valli', 'children', 'charles_farrell']
# ('cosimo_i_de_medici_grand_duke_of_tuscany', 'parents', 'maria_salviati')
# ['cosimo_i_de_medici_grand_duke_of_tuscany', 'sibling', 'maria_salviati']
# ('ranavalona_iii_of_madagascar', 'spouse', 'rainilaiarivony')
# ['ranavalona_iii_of_madagascar', 'parents', 'rainilaiarivony']
# ('alexandre_brongniart', 'parents', 'alexandre-theodore_brongniart')
# ['alexandre_brongniart', 'spouse', 'alexandre-theodore_brongniart']
# ('prince_alfonso_count_of_caserta', 'children', 'prince_carlos_of_bourbon_two_sicilies')
# ['prince_alfonso_count_of_caserta', 'sibling', 'prince_carlos_of_bourbon_two_sicilies']
# ('ernest_augustus_i_of_hanover', 'parents', 'charlotte_of_mecklenburg-strelitz')
# ['ernest_augustus_i_of_hanover', 'spouse', 'charlotte_of_mecklenburg-strelitz']
# ('anne_of_cleves', 'spouse', 'henry_viii_of_england')
# ['anne_of_cleves', 'children', 'henry_viii_of_england']
# ('richard_plantagenet_3rd_duke_of_york', 'children', 'richard_iii_of_england')
# ['richard_plantagenet_3rd_duke_of_york', 'parents', 'richard_iii_of_england']
# ('vipsania_agrippina', 'parents', 'marcus_vipsanius_agrippa')
# ['vipsania_agrippina', 'children', 'marcus_vipsanius_agrippa']
# ('charlotte_brabantina_of_nassau', 'parents', 'charlotte_of_bourbon')
# ['charlotte_brabantina_of_nassau', 'sibling', 'charlotte_of_bourbon']
# ('mao_fumei', 'spouse', 'chiang_kai-shek')
# ['mao_fumei', 'parents', 'chiang_kai-shek']
# ('richard_lee_ii', 'children', 'henry_lee_i')
# ['richard_lee_ii', 'sibling', 'henry_lee_i']
# ('maria_clotilde_of_savoy', 'parents', 'victor_emmanuel_ii_of_italy')
# ['maria_clotilde_of_savoy', 'children', 'victor_emmanuel_ii_of_italy']
# ('james_i_of_scotland', 'spouse', 'joan_beaufort_queen_of_scotland')
# ['james_i_of_scotland', 'sibling', 'joan_beaufort_queen_of_scotland']
# ('louis_philippe_i_duke_of_orleans', 'parents', 'auguste_marie_johanna_of_baden_baden')
# ['louis_philippe_i_duke_of_orleans', 'spouse', 'auguste_marie_johanna_of_baden_baden']
# ('james_ii_of_aragon', 'parents', 'peter_iii_of_aragon')
# ['james_ii_of_aragon', 'children', 'peter_iii_of_aragon']
# ('edmund_of_langley_1st_duke_of_york', 'spouse', 'isabella_of_castile_duchess_of_york')
# ['edmund_of_langley_1st_duke_of_york', 'parents', 'isabella_of_castile_duchess_of_york']
# ('henrietta_anne_stuart', 'children', 'maria_luisa_of_orleans')
# ['henrietta_anne_stuart', 'parents', 'maria_luisa_of_orleans']
# ('jesus', 'parents', 'blessed_virgin_mary')
# ['jesus', 'sibling', 'blessed_virgin_mary']
# ('amalie_adlerberg', 'spouse', 'nikolay_adlerberg')
# ['amalie_adlerberg', 'children', 'nikolay_adlerberg']
# ('princess_louise_marie_of_belgium', 'spouse', 'philipp_of_saxe-coburg-kohary')
# ['princess_louise_marie_of_belgium', 'children', 'philipp_of_saxe-coburg-kohary']
# ('xuande_emperor', 'parents', 'hongxi_emperor')
# ['xuande_emperor', 'children', 'hongxi_emperor']
# ('charles_ii_of_austria', 'children', 'anna_of_habsburg')
# ['charles_ii_of_austria', 'spouse', 'anna_of_habsburg']
# ('philippe_charles_3rd_count_of_arenberg', 'parents', 'anne_de_croy')
# ['philippe_charles_3rd_count_of_arenberg', 'children', 'anne_de_croy']
# ('dorothy_goetz', 'spouse', 'irving_berlin')
# ['dorothy_goetz', 'children', 'irving_berlin']
# ('khufu', 'parents', 'hetepheres')
# ['khufu', 'sibling', 'hetepheres']
# ('pier_luigi_farnese_duke_of_parma', 'parents', 'pope_paul_iii')
# ['pier_luigi_farnese_duke_of_parma', 'children', 'pope_paul_iii']
# ('frank_bunker_gilbreth', 'children', 'frank_gilbreth_jr')
# ['frank_bunker_gilbreth', 'spouse', 'frank_gilbreth_jr']
# ('ippolito_de_medici', 'parents', 'giuliano_di_lorenzo_de_medici')
# ['ippolito_de_medici', 'sibling', 'giuliano_di_lorenzo_de_medici']
# ('frederick_john_robinson_1st_viscount_goderich', 'parents', 'mary_robinson_baroness_grantham')
# ['frederick_john_robinson_1st_viscount_goderich', 'children', 'mary_robinson_baroness_grantham']
# ('blanche_oelrichs', 'spouse', 'john_barrymore')
# ['blanche_oelrichs', 'children', 'john_barrymore']
# ('anna_hyatt_huntington', 'spouse', 'archer_m_huntington')
# ['anna_hyatt_huntington', 'parents', 'archer_m_huntington']
# ('infanta_isabel_maria_of_portugal', 'parents', 'john_vi_of_portugal')
# ['infanta_isabel_maria_of_portugal', 'children', 'john_vi_of_portugal']
# ('bob_jones_jr', 'parents', 'bob_jones_sr')
# ['bob_jones_jr', 'children', 'bob_jones_sr']
# ('rose_fitzgerald_kennedy', 'spouse', 'joseph_p_kennedy_sr')
# ['rose_fitzgerald_kennedy', 'parents', 'joseph_p_kennedy_sr']
# ('ivan_stephen_of_bulgaria', 'parents', 'anna_neda_of_serbia')
# ['ivan_stephen_of_bulgaria', 'spouse', 'anna_neda_of_serbia']
# ('yixuan_1st_prince_chun', 'parents', 'daoguang_emperor')
# ['yixuan_1st_prince_chun', 'children', 'daoguang_emperor']
# ('vasili_iii_of_russia', 'parents', 'sophia_paleologue')
# ['vasili_iii_of_russia', 'children', 'sophia_paleologue']
# ('ghazi_of_iraq', 'parents', 'faisal_i_of_iraq')
# ['ghazi_of_iraq', 'spouse', 'faisal_i_of_iraq']
# ('yanina_zhejmo', 'spouse', 'andrei_kostrichkin')
# ['yanina_zhejmo', 'parents', 'andrei_kostrichkin']
# ('georg_ii_duke_of_saxe_meiningen', 'children', 'frederick_johann_of_saxe-meiningen')
# ['georg_ii_duke_of_saxe_meiningen', 'parents', 'frederick_johann_of_saxe-meiningen']
# ('constance_of_arles', 'children', 'adela_capet')
# ['constance_of_arles', 'parents', 'adela_capet']
# ('isabella_of_castile', 'spouse', 'ferdinand_ii_of_aragon')
# ['isabella_of_castile', 'sibling', 'ferdinand_ii_of_aragon']
# ('alois_ii_prince_of_liechtenstein', 'parents', 'johann_i_josef_prince_of_liechtenstein')
# ['alois_ii_prince_of_liechtenstein', 'children', 'johann_i_josef_prince_of_liechtenstein']
# ('kara_or_e_petrovic', 'children', 'alexander_kara_or_evic_prince_of_serbia')
# ['kara_or_e_petrovic', 'sibling', 'alexander_kara_or_evic_prince_of_serbia']
# ('william_mcmahon', 'spouse', 'sonia_mcmahon')
# ['william_mcmahon', 'parents', 'sonia_mcmahon']
# ('harald_iv_of_norway', 'children', 'sigurd_ii_of_norway')
# ['harald_iv_of_norway', 'sibling', 'sigurd_ii_of_norway']
# ('angelica_van_buren', 'spouse', 'martin_van_buren')
# ['angelica_van_buren', 'parents', 'martin_van_buren']
# ('elizabeth_tilney', 'children', 'elizabeth_boleyn_countess_of_wiltshire')
# ['elizabeth_tilney', 'parents', 'elizabeth_boleyn_countess_of_wiltshire']
# ('harry_caray', 'children', 'skip_caray')
# ['harry_caray', 'parents', 'skip_caray']
# ('edward_stanley_3rd_earl_of_derby', 'parents', 'thomas_stanley_2nd_earl_of_derby')
# ['edward_stanley_3rd_earl_of_derby', 'children', 'thomas_stanley_2nd_earl_of_derby']
# ('thomas_jamison', 'children', 'john_jamison')
# ['thomas_jamison', 'sibling', 'john_jamison']
# ('alexander_prince_of_bulgaria', 'parents', 'julia_von_hauke')
# ['alexander_prince_of_bulgaria', 'children', 'julia_von_hauke']
# ('maria_theresa_of_austria', 'children', 'archduchess_maria_josepha_of_austria')
# ['maria_theresa_of_austria', 'parents', 'archduchess_maria_josepha_of_austria']
# ('gustaf_vi_adolf_of_sweden', 'children', 'prince_sigvard_duke_of_uppland')
# ['gustaf_vi_adolf_of_sweden', 'sibling', 'prince_sigvard_duke_of_uppland']
# ('philippa_of_lancaster', 'parents', 'john_of_gaunt_1st_duke_of_lancaster')
# ['philippa_of_lancaster', 'spouse', 'john_of_gaunt_1st_duke_of_lancaster']
# ('infanta_beatriz_of_spain', 'parents', 'victoria_eugenia_of_battenberg')
# ['infanta_beatriz_of_spain', 'spouse', 'victoria_eugenia_of_battenberg']
# ('princess_margaretha_of_sweden', 'parents', 'prince_carl_duke_of_vastergotland')
# ['princess_margaretha_of_sweden', 'children', 'prince_carl_duke_of_vastergotland']
# ('thutmose_ii', 'children', 'thutmose_iii')
# ['thutmose_ii', 'spouse', 'thutmose_iii']
# ('ludwig_i_of_bavaria', 'children', 'prince_adalbert_of_bavaria')
# ['ludwig_i_of_bavaria', 'parents', 'prince_adalbert_of_bavaria']
# ('julia_avita_mamaea', 'children', 'alexander_severus')
# ['julia_avita_mamaea', 'parents', 'alexander_severus']
# ('olimpia_mancini', 'spouse', 'eugene_maurice_of_savoy_carignano')
# ['olimpia_mancini', 'children', 'eugene_maurice_of_savoy_carignano']
# ('astrid_of_sweden', 'spouse', 'leopold_iii_of_belgium')
# ['astrid_of_sweden', 'sibling', 'leopold_iii_of_belgium']
# ('joseph_i_holy_roman_emperor', 'parents', 'eleonore-magdalena_of_neuburg')
# ['joseph_i_holy_roman_emperor', 'spouse', 'eleonore-magdalena_of_neuburg']
# ('sviatopolk_ii_of_kiev', 'parents', 'gertrude_of_poland')
# ['sviatopolk_ii_of_kiev', 'sibling', 'gertrude_of_poland']
# ('john_dudley_1st_duke_of_northumberland', 'parents', 'edmund_dudley')
# ['john_dudley_1st_duke_of_northumberland', 'sibling', 'edmund_dudley']
# ('george_curzon_1st_marquess_curzon_of_kedleston', 'spouse', 'grace_curzon_marchioness_curzon_of_kedleston')
# ['george_curzon_1st_marquess_curzon_of_kedleston', 'sibling', 'grace_curzon_marchioness_curzon_of_kedleston']
# ('prince_philippe_count_of_flanders', 'spouse', 'princess_marie_of_hohenzollern_sigmaringen')
# ['prince_philippe_count_of_flanders', 'parents', 'princess_marie_of_hohenzollern_sigmaringen']
# ('ferdinand_georg_of_saxe-coburg-gotha', 'parents', 'franz_frederick_anton_duke_of_saxe_coburg_saalfeld')
# ['ferdinand_georg_of_saxe-coburg-gotha', 'sibling', 'franz_frederick_anton_duke_of_saxe_coburg_saalfeld']
# ('afonso_i_of_portugal', 'children', 'sancho_i_of_portugal')
# ['afonso_i_of_portugal', 'sibling', 'sancho_i_of_portugal']
# ('lilli_palmer', 'spouse', 'carlos_thompson')
# ['lilli_palmer', 'sibling', 'carlos_thompson']
# ('albert_ii_duke_of_austria', 'parents', 'albert_i_of_germany')
# ['albert_ii_duke_of_austria', 'spouse', 'albert_i_of_germany']
# ('peter_ii_of_portugal', 'spouse', 'maria_sofia_of_the_palatinate')
# ['peter_ii_of_portugal', 'sibling', 'maria_sofia_of_the_palatinate']
# ('sophia_of_lithuania', 'children', 'vasili_ii_of_russia')
# ['sophia_of_lithuania', 'spouse', 'vasili_ii_of_russia']
# ('stephen_of_england', 'children', 'eustace_iv_of_boulogne')
# ['stephen_of_england', 'parents', 'eustace_iv_of_boulogne']
# ('nikolai_rimsky-korsakov', 'spouse', 'nadezhda_rimskaya_korsakova')
# ['nikolai_rimsky-korsakov', 'children', 'nadezhda_rimskaya_korsakova']
# ('princess_mary_of_great_britain', 'parents', 'caroline_of_ansbach')
# ['princess_mary_of_great_britain', 'sibling', 'caroline_of_ansbach']
# ('isabella_duchess_of_lorraine', 'parents', 'charles_ii_duke_of_lorraine')
# ['isabella_duchess_of_lorraine', 'children', 'charles_ii_duke_of_lorraine']
# ('william_h_hinton', 'parents', 'carmelita_hinton')
# ['william_h_hinton', 'children', 'carmelita_hinton']
# ('edward_the_confessor', 'parents', 'godwin_earl_of_wessex')
# ['edward_the_confessor', 'sibling', 'godwin_earl_of_wessex']
# ('elisabeth_of_austria', 'spouse', 'casimir_iv_jagiellon')
# ['elisabeth_of_austria', 'sibling', 'casimir_iv_jagiellon']

# %% [markdown]
# ### 4. True links from Experiment 3

# %%
tuning_path = "../../../../akbc2021/akbc_2021/OpenKE/benchmarks/fb13_resplit/commonsense_benchmark_for_tuning_v2.json"
analysis_path = "../../../../akbc2021/akbc_2021/OpenKE/benchmarks/fb13_resplit/commonsense_benchmark_for_analysis_v2.json"

# %%
data = {}
with open(tuning_path) as f:
    data["tuning"] = json.load(f)

with open(analysis_path) as f:
    data["analysis"] = json.load(f)

# %%
triples = []
category = "parents"
for d in data["analysis"]:
    if d['category'] == category:
        triples.append(d["query_triple"])

# %%
with open(f'data/data_4d.pickle', 'wb') as handle:
    pickle.dump(triples, handle, protocol=pickle.HIGHEST_PROTOCOL)
