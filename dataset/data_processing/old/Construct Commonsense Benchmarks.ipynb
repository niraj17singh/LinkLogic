# %%
import pandas as pd
import networkx as nx
from tqdm import tqdm

# %%
data_dir = '../data/fb13/'
benchmarks = dict()

# %% [markdown]
# ### Load data and construct networkx graph object

# %%
def read_triples(file, **addl_cols):
    triples = pd.read_csv(file, sep='\t', names=['e1', 'rel', 'e2'])
    for key, value in addl_cols.items():
        triples[key] = value
    return triples

def construct_networkx_object(df_triples, df_entities):
    G = nx.MultiDiGraph()

    # add nodes
    print('adding nodes')
    e_tuples = [(row['name'], {'id': row['id']}) for i, row in df_entities.iterrows()]
    G.add_nodes_from(e_tuples)
    
    # add edges
    print('adding edges')
    for i, row in tqdm(df_triples.iterrows(), total=df_triples.shape[0]):
        G.add_edge(row.e1, row.e2, relation=row.rel)
        
    assert nx.number_of_nodes(G) == df_entities.shape[0]
        
    return G

# %%
# Read in all triples
splits = ['train', 'valid', 'test']
g_list = [read_triples(f'{data_dir}/{split}.txt', split=split) for split in splits]
g = pd.concat(g_list, axis=0)

# Read in entity info
entities = pd.read_csv(f'{data_dir}/entity2id.txt', sep='\t', names=['name', 'id'])

# %%
G = { split: construct_networkx_object(g[g.split == split], entities) for split in splits}
G['full'] = construct_networkx_object(g, entities)
# Out:
# adding nodes
#   0%|          | 890/316232 [00:00<00:35, 8890.05it/s]
# adding edges
# 100%|██████████| 316232/316232 [00:36<00:00, 8732.33it/s]
# adding nodes
#  32%|███▏      | 1869/5908 [00:00<00:00, 9353.75it/s]
# adding edges
# 100%|██████████| 5908/5908 [00:00<00:00, 9295.36it/s]
# adding nodes
#   3%|▎         | 797/23733 [00:00<00:02, 7949.10it/s]
# adding edges
# 100%|██████████| 23733/23733 [00:02<00:00, 8716.77it/s]
# adding nodes
#   0%|          | 866/345873 [00:00<00:39, 8658.96it/s]
# adding edges
# 100%|██████████| 345873/345873 [00:40<00:00, 8538.09it/s]

# %% [markdown]
# ### Helper functions for benchmark construction

# %%
def check_for_edge(G, u, v, rel):
    return (u, v, {'relation': rel}) in G.edges(data=True)

def construct_symmetric_edge_bmk(triples_df, G, predict_relation, explain_relation):
    bmk = []

    for _, row in triples_df.iterrows():

        explain_triple = (row.e2, row.e1, explain_relation)

        # if the reverse 'children' edge is in the graph at all, add it to the benchmark
        if check_for_edge(G['full'], *explain_triple):
            out = {'triple': (row.e1, predict_relation, row.e2),
                   'explanation': (row.e2, explain_relation, row.e1)}

            # if that edge is in training, set explanation_in_train to 1
            if check_for_edge(G['train'], *explain_triple):
                out['explanation_in_train'] = 1
            else:
                out['explanation_in_train'] = 0

            # if that edge is in test, set explanation_in_test to 1. However we know
            # this is not true since we only have parent edges in the test set.
            out['explanation_in_test'] = 0

            bmk.append(out)
            
    return bmk

def construct_explanation_benchmark(triples_to_explain, G, explanation_metapaths):
    bmk = []

    for _, row in triples_to_explain.iterrows():
        
        for metapath in explanation_metapaths:
            
            # if (any examples of the) metapath are in the graph, add them as explanations
            
            # for each path, compute the fraction of its edges that are in train, valid and test
            # (and assert this adds up to 1)

            explain_triple = (row.e2, row.e1, explain_relation)

            # if the reverse 'children' edge is in the graph at all, add it to the benchmark
            if check_for_edge(G['full'], *explain_triple):
                out = {'triple': (row.e1, predict_relation, row.e2),
                       'explanation': (row.e2, explain_relation, row.e1)}

                # if that edge is in training, set explanation_in_train to 1
                if check_for_edge(G['train'], *explain_triple):
                    out['explanation_in_train'] = 1
                else:
                    out['explanation_in_train'] = 0

                # if that edge is in test, set explanation_in_test to 1. However we know
                # this is not true since we only have parent edges in the test set.
                out['explanation_in_test'] = 0

                bmk.append(out)
            
    return bmk

# TO DO: change interface to check_for_edge to be edges and not G

# a path could be represented as a list of edges
#metapath = (entity1, relation1, entity2, relation2, entity3)
#or 
#metapath = (entity1, relation1, x, relation2, entity3)

# %%
full_edge = ('charles_studd', 'missionary', {'relation': 'profession'}) 
partial_edge = ('charles_studd', None, {'relation': 'profession'})
edges = G['test'].edges(data=True)

# %%
class Edge:
    
    def __init__(self, u, v, rel):
        self.u = u
        self.v = v
        self.rel = rel
        
    def __str__(self):
        return f'{self.u}--[{self.rel}]-->{self.v}'
    
    def __eq__(self, other):
        assert type(self) == type(other)
        
        if self.u == other.u and self.v == other.v and self.rel == other.rel:
            return True
        else:
            return False
        
class MetaEdge:
    
    def __init__(self, u=None, v=None, rel=None):
        self.u = u
        self.u_str = self._stringify(u)
        
        self.v = v
        self.v_str = self._stringify(v)
        
        self.rel = rel
        self.rel_str = self._stringify(rel)
        
    def __str__(self):
        e = Edge(self.u_str, self.v_str, self.rel_str)
        return e.__str__()
    
    def _stringify(self, elt):
        if elt is None:
            s = 'X'
        else:
            s = elt
        return s
            
class Path:
    pass

# %%
e1 = Edge(u='charles_studd', v='missionary', rel='profession')
e2 = MetaEdge(u='charles_studd', v='missionary')
#e1 == e2
print(e1)
print(e2)
# Out:
# charles_studd--[profession]-->missionary
# charles_studd--[X]-->missionary

# %%
type(e)
# Out:
# __main__.Edge

# %%
def find_edges(edges, constraints, verbose=False):
    assert len(constraints) == 3
    u, rel, v = constraints
    matches = []
    for edge in edges:
        match = True
        if u is not None and edge[0] != u:
            match = False
        if v is not None and edge[1] != v:
            match = False
        if rel is not None and edge[2]['relation'] != rel:
            match = False
        if match:
            matches.append(edge)
    found_edge = (len(matches) > 0)
    if verbose: print(f'Found {len(matches)} matching edges')
    return found_edge, matches

def find_two_hop_paths(edges, metapath):
    assert len(metapath) == 5
    hop1 = metapath[:3]
    hop2 = metapath[2:]
    
    found1, edges1 = find_edges(edges, constraints=hop1)
    found2, edges2 = find_edges(edges, constraints=hop2)
    
    paths = []
    if found1 and found2:
        for e1 in edges1:
            for e2 in edges2:
                if e2[1] == e1
                    path = ()
                    paths.append()

# %%
u = None
v = 'female'
rel = 'gender'
found, edge_subset = find_edges(edges, u=u, v=v, verbose=True)
# Out:
# Found 865 matching edges

# %%
metapath = ('A', 'rel1', 'x', 'rel2', 'B')
metapath[:3]
metapath[2:]
# Out:
# ('A', 'rel1', 'x')
# ('x', 'rel2', 'B')

# %% [markdown]
# ### Children benchmark

# %%
benchmarks = dict()
parents_test = read_triples(f'{data_dir}/test_parents.txt')
benchmarks['children'] = construct_symmetric_edge_bmk(parents_test, G, 'parents', 'children')

# %%
benchmarks
# Out:
# {'children': [{'triple': ('anna_e_roosevelt', 'parents', 'eleanor_roosevelt'),
#    'explanation': ('eleanor_roosevelt', 'children', 'anna_e_roosevelt'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ethel_lilian_voynich', 'parents', 'george_boole'),
#    'explanation': ('george_boole', 'children', 'ethel_lilian_voynich'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_sigismund_of_prussia_kiel',
#     'parents',
#     'princess_irene_of_hesse_and_by_rhine'),
#    'explanation': ('princess_irene_of_hesse_and_by_rhine',
#     'children',
#     'prince_sigismund_of_prussia_kiel'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('amun-her-khepeshef', 'parents', 'nefertari'),
#    'explanation': ('nefertari', 'children', 'amun-her-khepeshef'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('anna_of_bohemia', 'parents', 'constance_of_hungary'),
#    'explanation': ('constance_of_hungary', 'children', 'anna_of_bohemia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('techichpotzin', 'parents', 'moctezuma_ii'),
#    'explanation': ('moctezuma_ii', 'children', 'techichpotzin'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_maximilian_margrave_of_baden',
#     'parents',
#     'prince_berthold_margrave_of_baden'),
#    'explanation': ('prince_berthold_margrave_of_baden',
#     'children',
#     'prince_maximilian_margrave_of_baden'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('johann_casimir_duke_of_saxe_coburg',
#     'parents',
#     'johann_frederick_ii_duke_of_saxony'),
#    'explanation': ('johann_frederick_ii_duke_of_saxony',
#     'children',
#     'johann_casimir_duke_of_saxe_coburg'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('william_of_blois', 'parents', 'matilda_of_boulogne'),
#    'explanation': ('matilda_of_boulogne', 'children', 'william_of_blois'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('joan_ii_of_naples', 'parents', 'charles_iii_of_naples'),
#    'explanation': ('charles_iii_of_naples', 'children', 'joan_ii_of_naples'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_i_of_denmark', 'parents', 'dorothea_of_brandenburg'),
#    'explanation': ('dorothea_of_brandenburg', 'children', 'john_i_of_denmark'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ferdinand_ii_of_the_two_sicilies',
#     'parents',
#     'maria_isabella_of_spain'),
#    'explanation': ('maria_isabella_of_spain',
#     'children',
#     'ferdinand_ii_of_the_two_sicilies'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('isabella_of_jerusalem', 'parents', 'amalric_i_of_jerusalem'),
#    'explanation': ('amalric_i_of_jerusalem',
#     'children',
#     'isabella_of_jerusalem'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('edith_craig', 'parents', 'edward_william_godwin'),
#    'explanation': ('edward_william_godwin', 'children', 'edith_craig'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_iii_prince_of_conde',
#     'parents',
#     'henry_iii_jules_de_bourbon_prince_de_conde'),
#    'explanation': ('henry_iii_jules_de_bourbon_prince_de_conde',
#     'children',
#     'louis_iii_prince_of_conde'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('thomas_digges', 'parents', 'leonard_digges'),
#    'explanation': ('leonard_digges', 'children', 'thomas_digges'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('marguerite_of_france', 'parents', 'maria_of_brabant'),
#    'explanation': ('maria_of_brabant', 'children', 'marguerite_of_france'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('franz_xaver_wolfgang_mozart', 'parents', 'constanze_mozart'),
#    'explanation': ('constanze_mozart',
#     'children',
#     'franz_xaver_wolfgang_mozart'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('catherine_de_medici',
#     'parents',
#     'madeleine_de_la_tour_dauvergne'),
#    'explanation': ('madeleine_de_la_tour_dauvergne',
#     'children',
#     'catherine_de_medici'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('penelope_blount_countess_of_devonshire',
#     'parents',
#     'walter_devereux_1st_earl_of_essex'),
#    'explanation': ('walter_devereux_1st_earl_of_essex',
#     'children',
#     'penelope_blount_countess_of_devonshire'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mehmed_vi', 'parents', 'abdulmecid'),
#    'explanation': ('abdulmecid', 'children', 'mehmed_vi'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_iii_of_france', 'parents', 'catherine_de_medici'),
#    'explanation': ('catherine_de_medici', 'children', 'henry_iii_of_france'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_tia', 'parents', 'seti_i'),
#    'explanation': ('seti_i', 'children', 'princess_tia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('marie_francois_sadi_carnot', 'parents', 'hippolyte_carnot'),
#    'explanation': ('hippolyte_carnot',
#     'children',
#     'marie_francois_sadi_carnot'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ludwig_august_of_saxe-coburg-kohary',
#     'parents',
#     'august_of_saxe-coburg-kohary'),
#    'explanation': ('august_of_saxe-coburg-kohary',
#     'children',
#     'ludwig_august_of_saxe-coburg-kohary'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ramesses_iii', 'parents', 'setnakhte'),
#    'explanation': ('setnakhte', 'children', 'ramesses_iii'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ulysses_s_grant_jr', 'parents', 'julia_grant'),
#    'explanation': ('julia_grant', 'children', 'ulysses_s_grant_jr'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_maurice_of_the_netherlands',
#     'parents',
#     'sophie_of_wurttemberg'),
#    'explanation': ('sophie_of_wurttemberg',
#     'children',
#     'prince_maurice_of_the_netherlands'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('laura_marx', 'parents', 'jenny_von_westphalen'),
#    'explanation': ('jenny_von_westphalen', 'children', 'laura_marx'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('elena_of_montenegro', 'parents', 'nicholas_i_of_montenegro'),
#    'explanation': ('nicholas_i_of_montenegro',
#     'children',
#     'elena_of_montenegro'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('cleopatra_selene', 'parents', 'cleopatra_vii_of_egypt'),
#    'explanation': ('cleopatra_vii_of_egypt', 'children', 'cleopatra_selene'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('wilhelmina_amalia_of_brunswick',
#     'parents',
#     'john_frederick_duke_of_brunswick_luneburg'),
#    'explanation': ('john_frederick_duke_of_brunswick_luneburg',
#     'children',
#     'wilhelmina_amalia_of_brunswick'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_iv_holy_roman_emperor',
#     'parents',
#     'henry_iii_holy_roman_emperor'),
#    'explanation': ('henry_iii_holy_roman_emperor',
#     'children',
#     'henry_iv_holy_roman_emperor'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alfred_gwynne_vanderbilt',
#     'parents',
#     'cornelius_vanderbilt_ii'),
#    'explanation': ('cornelius_vanderbilt_ii',
#     'children',
#     'alfred_gwynne_vanderbilt'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('diego_colon', 'parents', 'christopher_columbus'),
#    'explanation': ('christopher_columbus', 'children', 'diego_colon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_anna_sophie_of_denmark',
#     'parents',
#     'frederick_iii_of_denmark'),
#    'explanation': ('frederick_iii_of_denmark',
#     'children',
#     'princess_anna_sophie_of_denmark'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alexander_kara_or_evic_prince_of_serbia',
#     'parents',
#     'kara_or_e_petrovic'),
#    'explanation': ('kara_or_e_petrovic',
#     'children',
#     'alexander_kara_or_evic_prince_of_serbia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mary_harrison_mckee', 'parents', 'anna_harrison'),
#    'explanation': ('anna_harrison', 'children', 'mary_harrison_mckee'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('christina_of_sweden',
#     'parents',
#     'maria_eleonora_of_brandenburg'),
#    'explanation': ('maria_eleonora_of_brandenburg',
#     'children',
#     'christina_of_sweden'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('edward_of_norwich_2nd_duke_of_york',
#     'parents',
#     'edmund_of_langley_1st_duke_of_york'),
#    'explanation': ('edmund_of_langley_1st_duke_of_york',
#     'children',
#     'edward_of_norwich_2nd_duke_of_york'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('simeon_uro', 'parents', 'stefan_uro_iii_de_anski_of_serbia'),
#    'explanation': ('stefan_uro_iii_de_anski_of_serbia',
#     'children',
#     'simeon_uro'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('vratislaus_ii_of_bohemia', 'parents', 'judith_of_schweinfurt'),
#    'explanation': ('judith_of_schweinfurt',
#     'children',
#     'vratislaus_ii_of_bohemia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_margaret_of_prussia',
#     'parents',
#     'frederick_iii_german_emperor'),
#    'explanation': ('frederick_iii_german_emperor',
#     'children',
#     'princess_margaret_of_prussia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_antoine_duke_of_angouleme',
#     'parents',
#     'marie_therese_of_savoy'),
#    'explanation': ('marie_therese_of_savoy',
#     'children',
#     'louis_antoine_duke_of_angouleme'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('frederika_of_hanover',
#     'parents',
#     'ernest_augustus_iii_duke_of_brunswick'),
#    'explanation': ('ernest_augustus_iii_duke_of_brunswick',
#     'children',
#     'frederika_of_hanover'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('giuliano_di_lorenzo_de_medici', 'parents', 'lorenzo_de_medici'),
#    'explanation': ('lorenzo_de_medici',
#     'children',
#     'giuliano_di_lorenzo_de_medici'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_viii_of_england', 'parents', 'henry_vii_of_england'),
#    'explanation': ('henry_vii_of_england',
#     'children',
#     'henry_viii_of_england'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('richard_layton_butler', 'parents', 'richard_butler_1850'),
#    'explanation': ('richard_butler_1850', 'children', 'richard_layton_butler'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('niels_bohr', 'parents', 'christian_bohr'),
#    'explanation': ('christian_bohr', 'children', 'niels_bohr'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mir_mahmud_hotaki', 'parents', 'mirwais_khan_hotak'),
#    'explanation': ('mirwais_khan_hotak', 'children', 'mir_mahmud_hotaki'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('geoffrey_v_count_of_anjou', 'parents', 'fulk_of_jerusalem'),
#    'explanation': ('fulk_of_jerusalem',
#     'children',
#     'geoffrey_v_count_of_anjou'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lady_rose_mclaren',
#     'parents',
#     'charles_paget_6th_marquess_of_anglesey'),
#    'explanation': ('charles_paget_6th_marquess_of_anglesey',
#     'children',
#     'lady_rose_mclaren'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('raymond_asquith', 'parents', 'h_h_asquith'),
#    'explanation': ('h_h_asquith', 'children', 'raymond_asquith'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('saint_margaret_of_hungary', 'parents', 'bela_iv_of_hungary'),
#    'explanation': ('bela_iv_of_hungary',
#     'children',
#     'saint_margaret_of_hungary'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('stephen_i_of_hungary', 'parents', 'geza_of_hungary'),
#    'explanation': ('geza_of_hungary', 'children', 'stephen_i_of_hungary'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('frits_philips', 'parents', 'anton_philips'),
#    'explanation': ('anton_philips', 'children', 'frits_philips'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('leonora_of_england', 'parents', 'eleanor_of_aquitaine'),
#    'explanation': ('eleanor_of_aquitaine', 'children', 'leonora_of_england'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('montagu_bertie_2nd_earl_of_lindsey',
#     'parents',
#     'robert_bertie_1st_earl_of_lindsey'),
#    'explanation': ('robert_bertie_1st_earl_of_lindsey',
#     'children',
#     'montagu_bertie_2nd_earl_of_lindsey'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('gerald_ford', 'parents', 'leslie_lynch_king_sr'),
#    'explanation': ('leslie_lynch_king_sr', 'children', 'gerald_ford'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lucius_verus', 'parents', 'lucius_aelius'),
#    'explanation': ('lucius_aelius', 'children', 'lucius_verus'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('philip_iii_of_navarre', 'parents', 'louis_devreux'),
#    'explanation': ('louis_devreux', 'children', 'philip_iii_of_navarre'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('frederick_v_of_denmark',
#     'parents',
#     'sophia_magdalen_of_brandenburg-kulmbach'),
#    'explanation': ('sophia_magdalen_of_brandenburg-kulmbach',
#     'children',
#     'frederick_v_of_denmark'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('maria_of_brabant', 'parents', 'henry_iii_duke_of_brabant'),
#    'explanation': ('henry_iii_duke_of_brabant',
#     'children',
#     'maria_of_brabant'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('philip_ii_of_taranto', 'parents', 'philip_i_of_taranto'),
#    'explanation': ('philip_i_of_taranto', 'children', 'philip_ii_of_taranto'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mihailo_obrenovic_iii_prince_of_serbia',
#     'parents',
#     'milo_obrenovic_i_prince_of_serbia'),
#    'explanation': ('milo_obrenovic_i_prince_of_serbia',
#     'children',
#     'mihailo_obrenovic_iii_prince_of_serbia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('herod_archelaus', 'parents', 'herod_the_great'),
#    'explanation': ('herod_the_great', 'children', 'herod_archelaus'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lady_sarah_wilson',
#     'parents',
#     'john_spencer_churchill_7th_duke_of_marlborough'),
#    'explanation': ('john_spencer_churchill_7th_duke_of_marlborough',
#     'children',
#     'lady_sarah_wilson'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_xvi_of_france', 'parents', 'louis_dauphin_de_france'),
#    'explanation': ('louis_dauphin_de_france',
#     'children',
#     'louis_xvi_of_france'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('francis_hyacinth_duke_of_savoy',
#     'parents',
#     'victor_amadeus_i_duke_of_savoy'),
#    'explanation': ('victor_amadeus_i_duke_of_savoy',
#     'children',
#     'francis_hyacinth_duke_of_savoy'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_cromwell', 'parents', 'elizabeth_bourchier'),
#    'explanation': ('elizabeth_bourchier', 'children', 'henry_cromwell'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('anne_of_cleves', 'parents', 'john_iii_duke_of_cleves'),
#    'explanation': ('john_iii_duke_of_cleves', 'children', 'anne_of_cleves'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_the_pious', 'parents', 'charlemagne'),
#    'explanation': ('charlemagne', 'children', 'louis_the_pious'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('robert_c_wickliffe', 'parents', 'charles_a_wickliffe'),
#    'explanation': ('charles_a_wickliffe', 'children', 'robert_c_wickliffe'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_elizabeth_of_england',
#     'parents',
#     'henrietta_maria_of_france'),
#    'explanation': ('henrietta_maria_of_france',
#     'children',
#     'princess_elizabeth_of_england'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('william_ii_german_emperor',
#     'parents',
#     'frederick_iii_german_emperor'),
#    'explanation': ('frederick_iii_german_emperor',
#     'children',
#     'william_ii_german_emperor'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('catherine_carey', 'parents', 'mary_boleyn'),
#    'explanation': ('mary_boleyn', 'children', 'catherine_carey'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('galswintha', 'parents', 'athanagild'),
#    'explanation': ('athanagild', 'children', 'galswintha'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ray_bridwell_white', 'parents', 'alma_bridwell_white'),
#    'explanation': ('alma_bridwell_white', 'children', 'ray_bridwell_white'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lothair_of_france', 'parents', 'gerberga_of_saxony'),
#    'explanation': ('gerberga_of_saxony', 'children', 'lothair_of_france'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('tyrone_power', 'parents', 'tyrone_power_sr'),
#    'explanation': ('tyrone_power_sr', 'children', 'tyrone_power'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('augusta_of_cambridge',
#     'parents',
#     'princess_augusta_of_hesse-kassel'),
#    'explanation': ('princess_augusta_of_hesse-kassel',
#     'children',
#     'augusta_of_cambridge'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('charles_duke_of_lower_lorraine',
#     'parents',
#     'louis_iv_of_france'),
#    'explanation': ('louis_iv_of_france',
#     'children',
#     'charles_duke_of_lower_lorraine'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('rasmus_bartholin', 'parents', 'caspar_bartholin_the_elder'),
#    'explanation': ('caspar_bartholin_the_elder',
#     'children',
#     'rasmus_bartholin'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('natalia_alexeievna_of_russia',
#     'parents',
#     'countess_palatine_caroline_of_zweibrucken'),
#    'explanation': ('countess_palatine_caroline_of_zweibrucken',
#     'children',
#     'natalia_alexeievna_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('djedefra', 'parents', 'khufu'),
#    'explanation': ('khufu', 'children', 'djedefra'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_of_bourbon_duke_of_orleans',
#     'parents',
#     'francoise_marie_de_bourbon'),
#    'explanation': ('francoise_marie_de_bourbon',
#     'children',
#     'louis_of_bourbon_duke_of_orleans'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('robert_i_of_artois', 'parents', 'blanche_of_castile'),
#    'explanation': ('blanche_of_castile', 'children', 'robert_i_of_artois'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('enno_louis_prince_of_ostfriesland',
#     'parents',
#     'ulrich_ii_count_of_ostfriesland'),
#    'explanation': ('ulrich_ii_count_of_ostfriesland',
#     'children',
#     'enno_louis_prince_of_ostfriesland'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mieszko_iv_tanglefoot', 'parents', 'wladyslaw_ii_the_exile'),
#    'explanation': ('wladyslaw_ii_the_exile',
#     'children',
#     'mieszko_iv_tanglefoot'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_crown_prince_of_portugal',
#     'parents',
#     'john_iii_of_portugal'),
#    'explanation': ('john_iii_of_portugal',
#     'children',
#     'john_crown_prince_of_portugal'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('kikkawa_motoharu', 'parents', 'mori_motonari'),
#    'explanation': ('mori_motonari', 'children', 'kikkawa_motoharu'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('skip_caray', 'parents', 'harry_caray'),
#    'explanation': ('harry_caray', 'children', 'skip_caray'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_george_iii_elector_of_saxony',
#     'parents',
#     'john_george_ii_elector_of_saxony'),
#    'explanation': ('john_george_ii_elector_of_saxony',
#     'children',
#     'john_george_iii_elector_of_saxony'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('saovabha', 'parents', 'piam'),
#    'explanation': ('piam', 'children', 'saovabha'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('jochi', 'parents', 'borte'),
#    'explanation': ('borte', 'children', 'jochi'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('william_henry_vanderbilt', 'parents', 'cornelius_vanderbilt'),
#    'explanation': ('cornelius_vanderbilt',
#     'children',
#     'william_henry_vanderbilt'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('edward_the_black_prince', 'parents', 'edward_iii_of_england'),
#    'explanation': ('edward_iii_of_england',
#     'children',
#     'edward_the_black_prince'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('claudius', 'parents', 'nero_claudius_drusus'),
#    'explanation': ('nero_claudius_drusus', 'children', 'claudius'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('regina_crown_princess_of_austria',
#     'parents',
#     'georg_iii_duke_of_saxe_meiningen'),
#    'explanation': ('georg_iii_duke_of_saxe_meiningen',
#     'children',
#     'regina_crown_princess_of_austria'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('roy_e_disney', 'parents', 'roy_o_disney'),
#    'explanation': ('roy_o_disney', 'children', 'roy_e_disney'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('thomas_spurgeon', 'parents', 'charles_spurgeon'),
#    'explanation': ('charles_spurgeon', 'children', 'thomas_spurgeon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('frank_killam', 'parents', 'thomas_killam'),
#    'explanation': ('thomas_killam', 'children', 'frank_killam'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louisa_may_alcott', 'parents', 'amos_bronson_alcott'),
#    'explanation': ('amos_bronson_alcott', 'children', 'louisa_may_alcott'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_ii_of_england', 'parents', 'empress_matilda'),
#    'explanation': ('empress_matilda', 'children', 'henry_ii_of_england'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lady_cynthia_mosley',
#     'parents',
#     'mary_curzon_baroness_curzon_of_kedleston'),
#    'explanation': ('mary_curzon_baroness_curzon_of_kedleston',
#     'children',
#     'lady_cynthia_mosley'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('yixin_prince_gong', 'parents', 'daoguang_emperor'),
#    'explanation': ('daoguang_emperor', 'children', 'yixin_prince_gong'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('george_herbert_11th_earl_of_pembroke',
#     'parents',
#     'henry_herbert_10th_earl_of_pembroke'),
#    'explanation': ('henry_herbert_10th_earl_of_pembroke',
#     'children',
#     'george_herbert_11th_earl_of_pembroke'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lord_robert_manners',
#     'parents',
#     'john_manners_2nd_duke_of_rutland'),
#    'explanation': ('john_manners_2nd_duke_of_rutland',
#     'children',
#     'lord_robert_manners'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('takelot_iii', 'parents', 'osorkon_iii'),
#    'explanation': ('osorkon_iii', 'children', 'takelot_iii'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('victor_amadeus_iii_of_sardinia',
#     'parents',
#     'charles_emmanuel_iii_of_sardinia'),
#    'explanation': ('charles_emmanuel_iii_of_sardinia',
#     'children',
#     'victor_amadeus_iii_of_sardinia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_de_la_pole_2nd_duke_of_suffolk',
#     'parents',
#     'alice_de_la_pole'),
#    'explanation': ('alice_de_la_pole',
#     'children',
#     'john_de_la_pole_2nd_duke_of_suffolk'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('archduke_louis_of_austria',
#     'parents',
#     'leopold_ii_holy_roman_emperor'),
#    'explanation': ('leopold_ii_holy_roman_emperor',
#     'children',
#     'archduke_louis_of_austria'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('grand_duke_dmitri_konstantinovich_of_russia',
#     'parents',
#     'alexandra_iosifovna_of_altenburg'),
#    'explanation': ('alexandra_iosifovna_of_altenburg',
#     'children',
#     'grand_duke_dmitri_konstantinovich_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('david_carradine', 'parents', 'john_carradine'),
#    'explanation': ('john_carradine', 'children', 'david_carradine'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lady_cynthia_mosley',
#     'parents',
#     'george_curzon_1st_marquess_curzon_of_kedleston'),
#    'explanation': ('george_curzon_1st_marquess_curzon_of_kedleston',
#     'children',
#     'lady_cynthia_mosley'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('gautama_buddha', 'parents', 'queen_maya'),
#    'explanation': ('queen_maya', 'children', 'gautama_buddha'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_of_portugal', 'parents', 'manuel_i_of_portugal'),
#    'explanation': ('manuel_i_of_portugal', 'children', 'henry_of_portugal'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('sophia_dorothea_of_hanover',
#     'parents',
#     'sophia_dorothea_of_celle'),
#    'explanation': ('sophia_dorothea_of_celle',
#     'children',
#     'sophia_dorothea_of_hanover'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mette_marit_crown_princess_of_norway',
#     'parents',
#     'sven_o_hoiby'),
#    'explanation': ('sven_o_hoiby',
#     'children',
#     'mette_marit_crown_princess_of_norway'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('minamoto_no_sanetomo', 'parents', 'minamoto_no_yoritomo'),
#    'explanation': ('minamoto_no_yoritomo', 'children', 'minamoto_no_sanetomo'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_cecilie_of_greece_and_denmark',
#     'parents',
#     'prince_andrew_of_greece_and_denmark'),
#    'explanation': ('prince_andrew_of_greece_and_denmark',
#     'children',
#     'princess_cecilie_of_greece_and_denmark'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_sophia_dorothea_of_prussia',
#     'parents',
#     'sophia_dorothea_of_hanover'),
#    'explanation': ('sophia_dorothea_of_hanover',
#     'children',
#     'princess_sophia_dorothea_of_prussia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_stewart_2nd_earl_of_buchan',
#     'parents',
#     'robert_stewart_1st_duke_of_albany'),
#    'explanation': ('robert_stewart_1st_duke_of_albany',
#     'children',
#     'john_stewart_2nd_earl_of_buchan'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('justinus_van_nassau', 'parents', 'william_the_silent'),
#    'explanation': ('william_the_silent', 'children', 'justinus_van_nassau'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('thomas_thynne_1st_marquess_of_bath',
#     'parents',
#     'thomas_thynne_2nd_viscount_weymouth'),
#    'explanation': ('thomas_thynne_2nd_viscount_weymouth',
#     'children',
#     'thomas_thynne_1st_marquess_of_bath'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('nissanka_wijeyeratne', 'parents', 'edwin_wijeyeratne'),
#    'explanation': ('edwin_wijeyeratne', 'children', 'nissanka_wijeyeratne'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('maria_antonia_of_portugal',
#     'parents',
#     'adelaide_of_lowenstein_wertheim_rosenberg'),
#    'explanation': ('adelaide_of_lowenstein_wertheim_rosenberg',
#     'children',
#     'maria_antonia_of_portugal'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('frederick_edward_guest',
#     'parents',
#     'ivor_churchill_guest_1st_viscount_wimborne'),
#    'explanation': ('ivor_churchill_guest_1st_viscount_wimborne',
#     'children',
#     'frederick_edward_guest'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('postumus_junior', 'parents', 'postumus'),
#    'explanation': ('postumus', 'children', 'postumus_junior'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_howard_7th_duke_of_norfolk',
#     'parents',
#     'henry_howard_6th_duke_of_norfolk'),
#    'explanation': ('henry_howard_6th_duke_of_norfolk',
#     'children',
#     'henry_howard_7th_duke_of_norfolk'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('marie_of_boulogne', 'parents', 'stephen_of_england'),
#    'explanation': ('stephen_of_england', 'children', 'marie_of_boulogne'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('tutankhamun', 'parents', 'nefertiti'),
#    'explanation': ('nefertiti', 'children', 'tutankhamun'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_sophia_dorothea_of_prussia',
#     'parents',
#     'frederick_william_i_of_prussia'),
#    'explanation': ('frederick_william_i_of_prussia',
#     'children',
#     'princess_sophia_dorothea_of_prussia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_f_kennedy_jr', 'parents', 'john_f_kennedy'),
#    'explanation': ('john_f_kennedy', 'children', 'john_f_kennedy_jr'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('grand_duchess_catherine_mikhailovna_of_russia',
#     'parents',
#     'grand_duke_michael_pavlovich_of_russia'),
#    'explanation': ('grand_duke_michael_pavlovich_of_russia',
#     'children',
#     'grand_duchess_catherine_mikhailovna_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_louis_ferdinand_of_bavaria',
#     'parents',
#     'infanta_amelia_philippina_of_spain'),
#    'explanation': ('infanta_amelia_philippina_of_spain',
#     'children',
#     'prince_louis_ferdinand_of_bavaria'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ronald_reagan', 'parents', 'nelle_wilson_reagan'),
#    'explanation': ('nelle_wilson_reagan', 'children', 'ronald_reagan'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('gerald_ford', 'parents', 'dorothy_ayer_gardner_ford'),
#    'explanation': ('dorothy_ayer_gardner_ford', 'children', 'gerald_ford'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('rudyard_kipling', 'parents', 'john_lockwood_kipling'),
#    'explanation': ('john_lockwood_kipling', 'children', 'rudyard_kipling'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('elena_of_greece_and_denmark',
#     'parents',
#     'constantine_i_of_greece'),
#    'explanation': ('constantine_i_of_greece',
#     'children',
#     'elena_of_greece_and_denmark'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('pope_leo_x', 'parents', 'lorenzo_de_medici'),
#    'explanation': ('lorenzo_de_medici', 'children', 'pope_leo_x'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('arcadius', 'parents', 'theodosius_i'),
#    'explanation': ('theodosius_i', 'children', 'arcadius'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louise_elisabeth_of_orleans',
#     'parents',
#     'francoise_marie_de_bourbon'),
#    'explanation': ('francoise_marie_de_bourbon',
#     'children',
#     'louise_elisabeth_of_orleans'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('felipe_prospero_of_habsburg', 'parents', 'philip_iv_of_spain'),
#    'explanation': ('philip_iv_of_spain',
#     'children',
#     'felipe_prospero_of_habsburg'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('catharina_of_sweden', 'parents', 'charles_ix_of_sweden'),
#    'explanation': ('charles_ix_of_sweden', 'children', 'catharina_of_sweden'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_caroline_elizabeth_of_great_britain',
#     'parents',
#     'george_ii_of_great_britain'),
#    'explanation': ('george_ii_of_great_britain',
#     'children',
#     'princess_caroline_elizabeth_of_great_britain'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mihrimar', 'parents', 'roxelana'),
#    'explanation': ('roxelana', 'children', 'mihrimar'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('geza_of_hungary', 'parents', 'taksony_of_hungary'),
#    'explanation': ('taksony_of_hungary', 'children', 'geza_of_hungary'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('amenemopet', 'parents', 'psusennes_i'),
#    'explanation': ('psusennes_i', 'children', 'amenemopet'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('w_averell_harriman', 'parents', 'e_h_harriman'),
#    'explanation': ('e_h_harriman', 'children', 'w_averell_harriman'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mikolaj_vii_radziwill', 'parents', 'katarzyna_tomicka'),
#    'explanation': ('katarzyna_tomicka', 'children', 'mikolaj_vii_radziwill'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('james_a_bayard_jr', 'parents', 'james_a_bayard'),
#    'explanation': ('james_a_bayard', 'children', 'james_a_bayard_jr'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('peter_van_pels', 'parents', 'hermann_van_pels'),
#    'explanation': ('hermann_van_pels', 'children', 'peter_van_pels'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('george_grossmith_jr', 'parents', 'george_grossmith'),
#    'explanation': ('george_grossmith', 'children', 'george_grossmith_jr'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ernest_elector_of_saxony',
#     'parents',
#     'frederick_ii_elector_of_saxony'),
#    'explanation': ('frederick_ii_elector_of_saxony',
#     'children',
#     'ernest_elector_of_saxony'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('otto_i_duke_of_saxony', 'parents', 'liudolf_duke_of_saxony'),
#    'explanation': ('liudolf_duke_of_saxony',
#     'children',
#     'otto_i_duke_of_saxony'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('don_carlos_prince_of_asturias',
#     'parents',
#     'maria_manuela_of_portugal'),
#    'explanation': ('maria_manuela_of_portugal',
#     'children',
#     'don_carlos_prince_of_asturias'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('harilal_gandhi', 'parents', 'kasturba_gandhi'),
#    'explanation': ('kasturba_gandhi', 'children', 'harilal_gandhi'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('clodoald', 'parents', 'chlodomer'),
#    'explanation': ('chlodomer', 'children', 'clodoald'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('anna_deste', 'parents', 'renee_of_france'),
#    'explanation': ('renee_of_france', 'children', 'anna_deste'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('eadgifu_of_england', 'parents', 'edward_the_elder'),
#    'explanation': ('edward_the_elder', 'children', 'eadgifu_of_england'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('andrey_bolshoy', 'parents', 'vasili_ii_of_russia'),
#    'explanation': ('vasili_ii_of_russia', 'children', 'andrey_bolshoy'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('zack_james_bellar', 'parents', 'troy_ryan_bellar'),
#    'explanation': ('troy_ryan_bellar', 'children', 'zack_james_bellar'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('anna_jagiellon', 'parents', 'bona_sforza'),
#    'explanation': ('bona_sforza', 'children', 'anna_jagiellon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('robert_i_duke_of_burgundy', 'parents', 'robert_ii_of_france'),
#    'explanation': ('robert_ii_of_france',
#     'children',
#     'robert_i_duke_of_burgundy'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('hussein_of_jordan', 'parents', 'talal_of_jordan'),
#    'explanation': ('talal_of_jordan', 'children', 'hussein_of_jordan'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('charles_ferdinand_duc_de_berry',
#     'parents',
#     'charles_x_of_france'),
#    'explanation': ('charles_x_of_france',
#     'children',
#     'charles_ferdinand_duc_de_berry'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('chagatai_khan', 'parents', 'genghis_khan'),
#    'explanation': ('genghis_khan', 'children', 'chagatai_khan'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('frank_reicher', 'parents', 'emanuel_reicher'),
#    'explanation': ('emanuel_reicher', 'children', 'frank_reicher'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('caligula', 'parents', 'germanicus'),
#    'explanation': ('germanicus', 'children', 'caligula'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_augusta_charlotte_of_wales',
#     'parents',
#     'princess_augusta_of_saxe-gotha'),
#    'explanation': ('princess_augusta_of_saxe-gotha',
#     'children',
#     'princess_augusta_charlotte_of_wales'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('michal_gedeon_radziwill',
#     'parents',
#     'michal_hieronim_radziwill'),
#    'explanation': ('michal_hieronim_radziwill',
#     'children',
#     'michal_gedeon_radziwill'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('eleanor_of_provence',
#     'parents',
#     'ramon_berenguer_iv_count_of_provence'),
#    'explanation': ('ramon_berenguer_iv_count_of_provence',
#     'children',
#     'eleanor_of_provence'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('catherine_of_braganza', 'parents', 'john_iv_of_portugal'),
#    'explanation': ('john_iv_of_portugal', 'children', 'catherine_of_braganza'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('buster_keaton', 'parents', 'joe_keaton'),
#    'explanation': ('joe_keaton', 'children', 'buster_keaton'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_the_lion', 'parents', 'gertrud_of_supplingenburg'),
#    'explanation': ('gertrud_of_supplingenburg', 'children', 'henry_the_lion'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('sviatoslav_ii_of_kiev', 'parents', 'olof_of_sweden'),
#    'explanation': ('olof_of_sweden', 'children', 'sviatoslav_ii_of_kiev'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('edward_ellice_1810', 'parents', 'edward_ellice'),
#    'explanation': ('edward_ellice', 'children', 'edward_ellice_1810'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('katherine_mortimer_countess_of_warwick',
#     'parents',
#     'roger_de_mortimer_1st_earl_of_march'),
#    'explanation': ('roger_de_mortimer_1st_earl_of_march',
#     'children',
#     'katherine_mortimer_countess_of_warwick'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ogden_l_mills', 'parents', 'ogden_mills'),
#    'explanation': ('ogden_mills', 'children', 'ogden_l_mills'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('charlotte_lee_lady_baltimore',
#     'parents',
#     'edward_lee_1st_earl_of_lichfield'),
#    'explanation': ('edward_lee_1st_earl_of_lichfield',
#     'children',
#     'charlotte_lee_lady_baltimore'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('george_ii_of_great_britain',
#     'parents',
#     'george_i_of_great_britain'),
#    'explanation': ('george_i_of_great_britain',
#     'children',
#     'george_ii_of_great_britain'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alfonso_v_of_leon', 'parents', 'bermudo_ii_of_leon'),
#    'explanation': ('bermudo_ii_of_leon', 'children', 'alfonso_v_of_leon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('william_kissam_vanderbilt',
#     'parents',
#     'william_henry_vanderbilt'),
#    'explanation': ('william_henry_vanderbilt',
#     'children',
#     'william_kissam_vanderbilt'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('vittorio_emanuele_count_of_turin',
#     'parents',
#     'amadeo_i_of_spain'),
#    'explanation': ('amadeo_i_of_spain',
#     'children',
#     'vittorio_emanuele_count_of_turin'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('boleslaw_ii_of_poland', 'parents', 'casimir_i_of_poland'),
#    'explanation': ('casimir_i_of_poland', 'children', 'boleslaw_ii_of_poland'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('yolande_of_jerusalem', 'parents', 'maria_of_montferrat'),
#    'explanation': ('maria_of_montferrat', 'children', 'yolande_of_jerusalem'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('grand_duke_george_mikhailovich_of_russia',
#     'parents',
#     'olga_feodorovna_grand_duchess_of_russia'),
#    'explanation': ('olga_feodorovna_grand_duchess_of_russia',
#     'children',
#     'grand_duke_george_mikhailovich_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('jinpyeong_of_silla', 'parents', 'jinheung_of_silla'),
#    'explanation': ('jinheung_of_silla', 'children', 'jinpyeong_of_silla'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('charles_lennox_2nd_duke_of_richmond',
#     'parents',
#     'charles_lennox_1st_duke_of_richmond'),
#    'explanation': ('charles_lennox_1st_duke_of_richmond',
#     'children',
#     'charles_lennox_2nd_duke_of_richmond'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_i_duke_of_guise', 'parents', 'anna_deste'),
#    'explanation': ('anna_deste', 'children', 'henry_i_duke_of_guise'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alfonso_i_deste', 'parents', 'leonora_of_naples'),
#    'explanation': ('leonora_of_naples', 'children', 'alfonso_i_deste'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_dalrymple_2nd_earl_of_stair',
#     'parents',
#     'john_dalrymple_1st_earl_of_stair'),
#    'explanation': ('john_dalrymple_1st_earl_of_stair',
#     'children',
#     'john_dalrymple_2nd_earl_of_stair'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('edward_salisbury_dana', 'parents', 'james_dwight_dana'),
#    'explanation': ('james_dwight_dana', 'children', 'edward_salisbury_dana'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lynn_redgrave', 'parents', 'michael_redgrave'),
#    'explanation': ('michael_redgrave', 'children', 'lynn_redgrave'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('sanchia_of_provence',
#     'parents',
#     'ramon_berenguer_iv_count_of_provence'),
#    'explanation': ('ramon_berenguer_iv_count_of_provence',
#     'children',
#     'sanchia_of_provence'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alexander_ii_of_russia', 'parents', 'alexandra_fyodorovna'),
#    'explanation': ('alexandra_fyodorovna',
#     'children',
#     'alexander_ii_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('george_formby', 'parents', 'george_formby_ashton_under_lyne'),
#    'explanation': ('george_formby_ashton_under_lyne',
#     'children',
#     'george_formby'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('adolphus_busch_iii', 'parents', 'august_anheuser_busch_sr'),
#    'explanation': ('august_anheuser_busch_sr',
#     'children',
#     'adolphus_busch_iii'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_philippe_i_duke_of_orleans',
#     'parents',
#     'louis_of_bourbon_duke_of_orleans'),
#    'explanation': ('louis_of_bourbon_duke_of_orleans',
#     'children',
#     'louis_philippe_i_duke_of_orleans'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('qianlong_emperor', 'parents', 'yongzheng_emperor'),
#    'explanation': ('yongzheng_emperor', 'children', 'qianlong_emperor'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ramon_berenguer_i_count_of_barcelona',
#     'parents',
#     'berenguer_ramon_i_count_of_barcelona'),
#    'explanation': ('berenguer_ramon_i_count_of_barcelona',
#     'children',
#     'ramon_berenguer_i_count_of_barcelona'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('thutmose_iv', 'parents', 'amenhotep_ii'),
#    'explanation': ('amenhotep_ii', 'children', 'thutmose_iv'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alfonso_iv_of_leon', 'parents', 'ordono_ii_of_leon'),
#    'explanation': ('ordono_ii_of_leon', 'children', 'alfonso_iv_of_leon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('a_k_faezul_huq', 'parents', 'a_k_fazlul_huq'),
#    'explanation': ('a_k_fazlul_huq', 'children', 'a_k_faezul_huq'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('wladyslaw_czartoryski', 'parents', 'adam_jerzy_czartoryski'),
#    'explanation': ('adam_jerzy_czartoryski',
#     'children',
#     'wladyslaw_czartoryski'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('caroline_of_bourbon_parma',
#     'parents',
#     'ferdinand_duke_of_parma'),
#    'explanation': ('ferdinand_duke_of_parma',
#     'children',
#     'caroline_of_bourbon_parma'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('isabella_of_france', 'parents', 'philip_iv_of_france'),
#    'explanation': ('philip_iv_of_france', 'children', 'isabella_of_france'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('augustus_keppel_1st_viscount_keppel',
#     'parents',
#     'willem_van_keppel_2nd_earl_of_albemarle'),
#    'explanation': ('willem_van_keppel_2nd_earl_of_albemarle',
#     'children',
#     'augustus_keppel_1st_viscount_keppel'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_somerset_9th_duke_of_beaufort',
#     'parents',
#     'henry_somerset_8th_duke_of_beaufort'),
#    'explanation': ('henry_somerset_8th_duke_of_beaufort',
#     'children',
#     'henry_somerset_9th_duke_of_beaufort'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_amelia_sophia_of_great_britain',
#     'parents',
#     'george_ii_of_great_britain'),
#    'explanation': ('george_ii_of_great_britain',
#     'children',
#     'princess_amelia_sophia_of_great_britain'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('gaston_comte_deu', 'parents', 'louis_duke_of_nemours'),
# ...
#    'explanation_in_test': 0},
#   {'triple': ('giovanni_dalle_bande_nere', 'parents', 'caterina_sforza'),
#    'explanation': ('caterina_sforza', 'children', 'giovanni_dalle_bande_nere'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_andrei_alexandrovich_of_russia',
#     'parents',
#     'grand_duke_alexander_mikhailovich_of_russia'),
#    'explanation': ('grand_duke_alexander_mikhailovich_of_russia',
#     'children',
#     'prince_andrei_alexandrovich_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('henry_vi_of_england', 'parents', 'catherine_of_valois'),
#    'explanation': ('catherine_of_valois', 'children', 'henry_vi_of_england'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alfred_gwynne_vanderbilt', 'parents', 'alice_claypoole_gwynne'),
#    'explanation': ('alice_claypoole_gwynne',
#     'children',
#     'alfred_gwynne_vanderbilt'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_marie_alexandra_of_baden',
#     'parents',
#     'prince_maximilian_of_baden'),
#    'explanation': ('prince_maximilian_of_baden',
#     'children',
#     'princess_marie_alexandra_of_baden'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('laurence_hyde_1st_earl_of_rochester',
#     'parents',
#     'edward_hyde_1st_earl_of_clarendon'),
#    'explanation': ('edward_hyde_1st_earl_of_clarendon',
#     'children',
#     'laurence_hyde_1st_earl_of_rochester'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('samuel_benjamin_sofer', 'parents', 'akiva_eger'),
#    'explanation': ('akiva_eger', 'children', 'samuel_benjamin_sofer'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('infante_luis_duke_of_beja', 'parents', 'manuel_i_of_portugal'),
#    'explanation': ('manuel_i_of_portugal',
#     'children',
#     'infante_luis_duke_of_beja'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('olga_konstantinovna_of_russia',
#     'parents',
#     'alexandra_iosifovna_of_altenburg'),
#    'explanation': ('alexandra_iosifovna_of_altenburg',
#     'children',
#     'olga_konstantinovna_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('muhammad_al-baqir', 'parents', 'ali_ibn_hussayn'),
#    'explanation': ('ali_ibn_hussayn', 'children', 'muhammad_al-baqir'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('menachem_mendel_schneerson',
#     'parents',
#     'joseph_isaac_schneersohn'),
#    'explanation': ('joseph_isaac_schneersohn',
#     'children',
#     'menachem_mendel_schneerson'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('nikola_obretenov', 'parents', 'tonka_obretenova'),
#    'explanation': ('tonka_obretenova', 'children', 'nikola_obretenov'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('olga_nicolaievna_of_russia', 'parents', 'alexandra_fyodorovna'),
#    'explanation': ('alexandra_fyodorovna',
#     'children',
#     'olga_nicolaievna_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('neil_james_archibald_primrose',
#     'parents',
#     'hannah_primrose_countess_of_rosebery'),
#    'explanation': ('hannah_primrose_countess_of_rosebery',
#     'children',
#     'neil_james_archibald_primrose'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('john_iii_of_portugal', 'parents', 'manuel_i_of_portugal'),
#    'explanation': ('manuel_i_of_portugal', 'children', 'john_iii_of_portugal'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('isabella_stewart_princess_of_scotland',
#     'parents',
#     'joan_beaufort_queen_of_scotland'),
#    'explanation': ('joan_beaufort_queen_of_scotland',
#     'children',
#     'isabella_stewart_princess_of_scotland'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('j_presper_eckert', 'parents', 'j_presper_eckert'),
#    'explanation': ('j_presper_eckert', 'children', 'j_presper_eckert'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_adalbert_of_bavaria', 'parents', 'ludwig_i_of_bavaria'),
#    'explanation': ('ludwig_i_of_bavaria',
#     'children',
#     'prince_adalbert_of_bavaria'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('nakkhatra_mangkala_kitiyakara',
#     'parents',
#     'kitiyakara_voralaksana'),
#    'explanation': ('kitiyakara_voralaksana',
#     'children',
#     'nakkhatra_mangkala_kitiyakara'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('william_cavendish_5th_duke_of_devonshire',
#     'parents',
#     'william_cavendish_4th_duke_of_devonshire'),
#    'explanation': ('william_cavendish_4th_duke_of_devonshire',
#     'children',
#     'william_cavendish_5th_duke_of_devonshire'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('eulalia_duchess_of_galliera',
#     'parents',
#     'isabella_ii_of_spain'),
#    'explanation': ('isabella_ii_of_spain',
#     'children',
#     'eulalia_duchess_of_galliera'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('james_johnstone_2nd_marquess_of_annandale',
#     'parents',
#     'william_johnstone_1st_marquess_of_annandale'),
#    'explanation': ('william_johnstone_1st_marquess_of_annandale',
#     'children',
#     'james_johnstone_2nd_marquess_of_annandale'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('giulia_de_medici',
#     'parents',
#     'alessandro_de_medici_duke_of_florence'),
#    'explanation': ('alessandro_de_medici_duke_of_florence',
#     'children',
#     'giulia_de_medici'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('maria_theresia_of_austria-este',
#     'parents',
#     'archduchess_elisabeth_franziska_of_austria'),
#    'explanation': ('archduchess_elisabeth_franziska_of_austria',
#     'children',
#     'maria_theresia_of_austria-este'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('jose_prince_of_brazil', 'parents', 'peter_iii_of_portugal'),
#    'explanation': ('peter_iii_of_portugal',
#     'children',
#     'jose_prince_of_brazil'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('rene_i_of_naples', 'parents', 'yolande_of_aragon'),
#    'explanation': ('yolande_of_aragon', 'children', 'rene_i_of_naples'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('donald_iii_of_scotland', 'parents', 'duncan_i_of_scotland'),
#    'explanation': ('duncan_i_of_scotland',
#     'children',
#     'donald_iii_of_scotland'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('william_stanley_6th_earl_of_derby',
#     'parents',
#     'lady_margaret_clifford'),
#    'explanation': ('lady_margaret_clifford',
#     'children',
#     'william_stanley_6th_earl_of_derby'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('archduchess_maria_josepha_of_austria',
#     'parents',
#     'francis_i_holy_roman_emperor'),
#    'explanation': ('francis_i_holy_roman_emperor',
#     'children',
#     'archduchess_maria_josepha_of_austria'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('petar_zrinski', 'parents', 'juraj_v_zrinski'),
#    'explanation': ('juraj_v_zrinski', 'children', 'petar_zrinski'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('mariano_fortuny', 'parents', 'mariano_fortuny_1838'),
#    'explanation': ('mariano_fortuny_1838', 'children', 'mariano_fortuny'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('sverre_of_norway', 'parents', 'sigurd_ii_of_norway'),
#    'explanation': ('sigurd_ii_of_norway', 'children', 'sverre_of_norway'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('constantine_vi', 'parents', 'leo_iv_the_khazar'),
#    'explanation': ('leo_iv_the_khazar', 'children', 'constantine_vi'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_josias_of_coburg',
#     'parents',
#     'franz_josias_duke_of_saxe_coburg_saalfeld'),
#    'explanation': ('franz_josias_duke_of_saxe_coburg_saalfeld',
#     'children',
#     'prince_josias_of_coburg'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('constantia_of_sicily', 'parents', 'manfred_of_sicily'),
#    'explanation': ('manfred_of_sicily', 'children', 'constantia_of_sicily'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('philip_ii_of_france', 'parents', 'adele_of_champagne'),
#    'explanation': ('adele_of_champagne', 'children', 'philip_ii_of_france'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ahmose_i', 'parents', 'tao_ii_the_brave'),
#    'explanation': ('tao_ii_the_brave', 'children', 'ahmose_i'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('jacqueline_de_longwy', 'parents', 'jeanne_of_angouleme'),
#    'explanation': ('jeanne_of_angouleme', 'children', 'jacqueline_de_longwy'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_louise_of_denmark_and_norway',
#     'parents',
#     'frederick_v_of_denmark'),
#    'explanation': ('frederick_v_of_denmark',
#     'children',
#     'princess_louise_of_denmark_and_norway'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('orhan_i', 'parents', 'osman_i'),
#    'explanation': ('osman_i', 'children', 'orhan_i'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('emanuele_filiberto_2nd_duke_of_aosta',
#     'parents',
#     'maria_victoria_al_pozzo_della_cisterna'),
#    'explanation': ('maria_victoria_al_pozzo_della_cisterna',
#     'children',
#     'emanuele_filiberto_2nd_duke_of_aosta'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('suzanne_duchess_of_bourbon', 'parents', 'anne_of_france'),
#    'explanation': ('anne_of_france', 'children', 'suzanne_duchess_of_bourbon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('isaac', 'parents', 'sarah'),
#    'explanation': ('sarah', 'children', 'isaac'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('elisabeth_charlotte_of_orleans',
#     'parents',
#     'elizabeth_charlotte_princess_palatine'),
#    'explanation': ('elizabeth_charlotte_princess_palatine',
#     'children',
#     'elisabeth_charlotte_of_orleans'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_augusta_of_saxe-gotha',
#     'parents',
#     'magdalena_augusta_of_anhalt_zerbst'),
#    'explanation': ('magdalena_augusta_of_anhalt_zerbst',
#     'children',
#     'princess_augusta_of_saxe-gotha'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ferdinand_iv_of_castile', 'parents', 'sancho_iv_of_castile'),
#    'explanation': ('sancho_iv_of_castile',
#     'children',
#     'ferdinand_iv_of_castile'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('charles_the_simple', 'parents', 'louis_the_stammerer'),
#    'explanation': ('louis_the_stammerer', 'children', 'charles_the_simple'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('archduke_charles_duke_of_teschen',
#     'parents',
#     'maria_louisa_of_spain'),
#    'explanation': ('maria_louisa_of_spain',
#     'children',
#     'archduke_charles_duke_of_teschen'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louis_ii_of_hungary_and_bohemia',
#     'parents',
#     'anna_of_foix-candale'),
#    'explanation': ('anna_of_foix-candale',
#     'children',
#     'louis_ii_of_hungary_and_bohemia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('archduke_rainer_of_austria',
#     'parents',
#     'maria_louisa_of_spain'),
#    'explanation': ('maria_louisa_of_spain',
#     'children',
#     'archduke_rainer_of_austria'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('charles_xv_of_sweden', 'parents', 'josephine_of_leuchtenberg'),
#    'explanation': ('josephine_of_leuchtenberg',
#     'children',
#     'charles_xv_of_sweden'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('georg_ii_duke_of_saxe_meiningen',
#     'parents',
#     'bernhard_ii_erich_freund_duke_of_saxe_meiningen'),
#    'explanation': ('bernhard_ii_erich_freund_duke_of_saxe_meiningen',
#     'children',
#     'georg_ii_duke_of_saxe_meiningen'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('grand_duchess_alexandra_alexandrovna_of_russia',
#     'parents',
#     'maria_alexandrovna_of_hesse'),
#    'explanation': ('maria_alexandrovna_of_hesse',
#     'children',
#     'grand_duchess_alexandra_alexandrovna_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('domino_harvey', 'parents', 'laurence_harvey'),
#    'explanation': ('laurence_harvey', 'children', 'domino_harvey'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('princess_margaret_of_connaught',
#     'parents',
#     'princess_louise_margaret_duchess_of_connaught'),
#    'explanation': ('princess_louise_margaret_duchess_of_connaught',
#     'children',
#     'princess_margaret_of_connaught'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('alexander_iii_of_russia',
#     'parents',
#     'maria_alexandrovna_of_hesse'),
#    'explanation': ('maria_alexandrovna_of_hesse',
#     'children',
#     'alexander_iii_of_russia'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('thomas_clifford_8th_lord_of_skipton',
#     'parents',
#     'john_clifford_7th_baron_de_clifford'),
#    'explanation': ('john_clifford_7th_baron_de_clifford',
#     'children',
#     'thomas_clifford_8th_lord_of_skipton'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('simchah_bunim_alter', 'parents', 'avraham_mordechai_alter'),
#    'explanation': ('avraham_mordechai_alter',
#     'children',
#     'simchah_bunim_alter'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('philip_ii_of_macedon', 'parents', 'amyntas_iii_of_macedon'),
#    'explanation': ('amyntas_iii_of_macedon',
#     'children',
#     'philip_ii_of_macedon'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('lord_george_lennox',
#     'parents',
#     'charles_lennox_2nd_duke_of_richmond'),
#    'explanation': ('charles_lennox_2nd_duke_of_richmond',
#     'children',
#     'lord_george_lennox'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('prince_alexander_of_hesse_and_by_rhine_darmstadt',
#     'parents',
#     'georg_donatus_hereditary_grand_duke_of_hesse'),
#    'explanation': ('georg_donatus_hereditary_grand_duke_of_hesse',
#     'children',
#     'prince_alexander_of_hesse_and_by_rhine_darmstadt'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('claude_of_valois', 'parents', 'henry_ii_of_france'),
#    'explanation': ('henry_ii_of_france', 'children', 'claude_of_valois'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('gheorghe_tasca', 'parents', 'gheorghe_i_tasca'),
#    'explanation': ('gheorghe_i_tasca', 'children', 'gheorghe_tasca'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('louise_marie_adelaide_eugenie_dorleans',
#     'parents',
#     'louise_marie_adelaide_de_bourbon_penthievre'),
#    'explanation': ('louise_marie_adelaide_de_bourbon_penthievre',
#     'children',
#     'louise_marie_adelaide_eugenie_dorleans'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('ramesses_iv', 'parents', 'ramesses_iii'),
#    'explanation': ('ramesses_iii', 'children', 'ramesses_iv'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   {'triple': ('infante_augusto_duke_of_coimbra',
#     'parents',
#     'maria_ii_of_portugal'),
#    'explanation': ('maria_ii_of_portugal',
#     'children',
#     'infante_augusto_duke_of_coimbra'),
#    'explanation_in_train': 1,
#    'explanation_in_test': 0},
#   ...]}

# %% [markdown]
# ### Spouse by symmetry

# %%
spouse_test = read_triples(f'{data_dir}/test_spouse.txt')
benchmarks['spouse_by_symmetry'] = construct_symmetric_edge_bmk(spouse_test, G, 'spouse', 'spouse')

# %% [markdown]
# ### Parent-child by co-parent

# %% [markdown]
# ### Nationality by family nationality

# %% [markdown]
# ### Location by various factors

# %%
G = nx.MultiDiGraph()

# %%
G.add_node(0)
G.add_node(1)

# %%
nx.number_of_nodes(G)

# %%
G.add_edge(0, 1, relation='red')
